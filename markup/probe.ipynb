# %% [markdown]
# # NB probe CANARY-NB-RENDERS
#
# <img src=x onerror=alert(1)>
# <script>alert(2)</script>

# %%
print('x')
# Out:
# <div>CANARY-NB-HTMLOUT</div><img src=x onerror=alert(3)><script>alert(4)</script><iframe src=//evil.example.com></iframe>
